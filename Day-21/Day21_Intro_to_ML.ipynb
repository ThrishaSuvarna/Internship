# %% [markdown]
# Machine Learning is a method where a computer learns from data instead of being programmed with fixed rules. In normal programming, we give the computer data and instructions, and it gives us the output. In Machine Learning, we give the computer data along with the correct outputs, and the computer learns the pattern by itself. Once it learns, it can use that knowledge to make predictions or decisions for new data without being told what to do step by step.
